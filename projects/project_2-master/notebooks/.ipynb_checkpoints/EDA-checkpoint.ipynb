# %% [markdown]
# ## Exploratory Data Analysis:

# %%
# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in Training Data

df_train = pd.read_csv('../datasets/train.csv')

# %%
# Convert all columns to lowercase and replace spaces in column names.

#df_train.columns = df_train.columns.str.lower().str.replace(' ', '_')

# %%
# Explore Training Data, first five rows:

df_train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %%
# How big is the dataset?

df_train.shape
# Out:
# (2051, 81)

# %%
# Observe data types and non-null counts:

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %%
# Identify Missing Data:

pd.set_option("display.max_rows", 999)
df_train.isnull().sum()
# Out:
# Id                    0
# PID                   0
# MS SubClass           0
# MS Zoning             0
# Lot Frontage        330
# Lot Area              0
# Street                0
# Alley              1911
# Lot Shape             0
# Land Contour          0
# Utilities             0
# Lot Config            0
# Land Slope            0
# Neighborhood          0
# Condition 1           0
# Condition 2           0
# Bldg Type             0
# House Style           0
# Overall Qual          0
# Overall Cond          0
# Year Built            0
# Year Remod/Add        0
# Roof Style            0
# Roof Matl             0
# Exterior 1st          0
# Exterior 2nd          0
# Mas Vnr Type         22
# Mas Vnr Area         22
# Exter Qual            0
# Exter Cond            0
# Foundation            0
# Bsmt Qual            55
# Bsmt Cond            55
# Bsmt Exposure        58
# BsmtFin Type 1       55
# BsmtFin SF 1          1
# BsmtFin Type 2       56
# BsmtFin SF 2          1
# ...

# %% [markdown]
# ## Evaluation of Variables with Missing Data:

# %% [markdown]
# Prework: Investigate all unique values and unique value counts for each column.
# If a variable has NA *AND* null values, consider dropping null values.
# If variable should have NA values according to datadict bus has none, fill.
# If numerical value is empty, consider imputing. If categorical and empty, see above line.
#
# **Lot Frontage**: Linear feet of street connected to property >> Set nulls to zero?
#
# **Alley**: Type of alley access, has an NA value >> are NAs present?
#
# **Mas Vnr Type**: Masonry Vineer type, has none value >> NAs present?
#
# **Mas Vnr Area**: Masonry veneer area in square feet >> if Mas Vnr Type is NA, should this be NA?
#
# **Bsmt Qual**: Height of the basement: Has NA value >> drop nulls if NAs are present?
#
# **Bsmt Cond**: General condition of the basement: Has NA values >> drop nulls?
#
# **Bsmt Exposure**: Walkout or garden level basement walls has NA value >> drop?
#
# **BsmtFin Type 1**: Type 1 finished square feet
#
# **BsmtFin SF 1**: Basement in square feet.
#
# **BsmtFin Type 2**: Quality of second finished area (if present): has NA value >> drop nulls?
#
# **BsmtFin SF 2**: Type 2 finished square feet >> if not present, drop BsmtFin Type 2 first, see if missing values still exist
#
# **Bsmt Unf SF**: Unfinished square feet of basement area >> do zeros exist? or null if no basement?
#
# **Total Bsmt SF**: Total square feet of basement area >> do zeros exist? if not, how many are left after adressing areas without a basement?
#
# **Bsmt Full Bath**: Basement full bathrooms >> is this incliuded in other bath count?
#
# **Bsmt Half Bath**: Basement half bathrooms >> included in other bath counts?
#
# **Fireplace Qu**: Fireplace quality >> assuming null if no fireplace?
#
# **Garage Type**: Garage location, has an NA value >> drop if NAs are present?
#
# **Garage Yr Blt**: Year garage was built, has NA value >> drop if NAs present?
#
# **Garage Finish**: Interior finish of the garage
#
# **Garage Cars**: Size of garage in car capacity >> null if no garage?
#
# **Garage Area**: Size of garage in square feet
#
# **Garage Qual**: Garage quality
#
# **Garage Cond**: Garage condition
#
# **Pool QC**: Pool quality, has NA value >> investigate pool sqft variable >> null if no pool?
#
# **Fence**: Fence quality >> empty if no fence
#
# **Misc Feature**: Miscellaneous feature not covered in other categories >> make dummy for has/hasnot

# %%
# It will likely be beneficial to summarize the below into groups for feature engineering: 

# Masonry
# Basement 
# Fireplace
# Garage
# Pool 
# Fence
# Misc

# %%
# Get descriptive statistics for numeric variables:

df_train.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# ...

# %% [markdown]
# ## Visualization of Data:

# %%
# Visualize int64 variables vs Sale Price:

int_dtypes = ['int64']

num_cols = []
for i in df_train.columns:
    if df_train[i].dtype in int_dtypes:
        num_cols.append(i)
    else:
        pass

# Using subplots instead of pairplot for readability

plt.subplots(figsize=(12, 120))
plt.subplots_adjust(right=1.5, top=1.5)
for i, feature in enumerate(list(df_train[num_cols]), 1):
    plt.subplot(len(list(num_cols)), 3, i)
    sns.scatterplot(x=feature, 
               y='SalePrice', 
               hue='SalePrice',
               palette='Blues',     
               data=df_train)
    plt.xlabel(f"{feature}", fontsize=14)
    plt.ylabel('SalePrice', fontsize=14);

# %%
# Visualize Float Variables vs SalePrice

flo_dtypes = ['float64']
flo_cols = []
for i in df_train.columns:
    if df_train[i].dtype in flo_dtypes:
        flo_cols.append(i)
    else:
        pass

# Using subplots instead of pairplot for readability

plt.subplots(figsize=(12, 120))
plt.subplots_adjust(right=1.5, top=1.5)
for i, feature in enumerate(list(df_train[flo_cols]), 1):
    plt.subplot(len(list(flo_cols)), 3, i)
    sns.scatterplot(x=feature,
                    y='SalePrice',
               palette='Blues',
               hue='SalePrice',
               data=df_train)
    plt.xlabel(f"{feature}", fontsize=12)
    plt.ylabel('Sale Price', fontsize=10);

# %%
# Visualize categorical variables:

object_dtypes = ['object'] # make seperate plots for integers and floats
cat_cols = []
for i in df_train.columns:
    if df_train[i].dtype in object_dtypes:
        cat_cols.append(i)
    else:
        pass
    
# Using subplots instead of pairplot for readability    
# Bars: 

plt.subplots(figsize=(14, 120))
plt.subplots_adjust(right=1.5, top=1.5)
for i, feature in enumerate(list(df_train[cat_cols]), 1):
    plt.subplot(len(list(cat_cols)), 3, i)
    sns.countplot(x=feature,
               data=df_train)
    plt.title(f'Frequency of {feature}', fontsize=12)
    plt.xlabel(f"{feature}", fontsize=12)
    plt.ylabel('Frequency', fontsize=10);

# %%
# Make some box plots? histograms??

# Do the below with the other ordinal variables we made

# %%
sns.boxplot(x='Overall Qual', y='SalePrice', palette='Blues', data=df_train)
plt.title('Overall Quality vs Sale Price', fontsize=14);

# %%
sns.boxplot(x='CATEGORICAL VALUE', y="SalePrice", data=df_train)
plt.title('Boxplot of X & Sale Price', fontsize=14);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-bc6d23a65ee7> in <module>
# ----> 1 sns.boxplot(x='CATEGORICAL VALUE', y="SalePrice", data=df_train)
#       2 plt.title('Boxplot of X & Sale Price', fontsize=14);
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2239     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2240                           orient, color, palette, saturation,
# -> 2241                           width, dodge, fliersize, linewidth)
#    2242
#    2243     if ax is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
# ...

# %%
# Histogram of numeric variables:

df_train.hist(figsize = (20,20));

# %%
 # sns.boxplot(df_train['', color='skyblue')

# %%
# Investigate Distribution of SalePrice:

df_train['SalePrice'].hist();

# Slightly skewed--will need to revisit this in feature engineering. 
# Possible .log transformation required.

# %% [markdown]
# ### Initial Observations:

# %%
# ERIC: Use these to visualize the most interesting variables. 

# Some functions to observe and clean data:

def plt_against_price(sale_price,feature):
    """Input sale_price variable (keep constant) and specific feature for analysis"""
    figure = plt.scatter(sale_price,feature)
    plt.xlabel('Sale Price')
    plt.ylabel('Feature')
    plt.title('Feature v Sale Price');
    return figure
def plt_distribution(feature,bin_num):
    """Input feature variable for distribution as histogram and specified number of bins"""
    figure = plt.hist(feature,bins=bin_num)
    plt.xlabel('Distribution')
    plt.ylabel('Feature')
    plt.title('Feature Distribution')
    return figure
def drop_outliers(feature,df,boolean):
    indexFeature = df[df[feature] boolean].index
    df.drop(indexFeature,inplace=True)
    return df
# Out:
#   File "<ipython-input-29-70acc6dc62eb>", line 16
#     indexFeature = df[df[feature] boolean].index
#                                         ^
# SyntaxError: invalid syntax

# %%
 def drop_outliers(feature,df,boolean):
    indexFeature = df[df[feature] boolean].index
    df.drop(indexFeature,inplace=True)
    return df
# Out:
#   File "<ipython-input-71-ce3e31d894f8>", line 2
#     indexFeature = df[df[feature] boolean].index
#                                         ^
# SyntaxError: invalid syntax

# %%
# Chuck EDA function
def eda(dataframe):
    print("MISSING VALUES:\n{}\n".format(dataframe.isnull().sum()))
    print("INDEX:\n{}\n".format(dataframe.index))
    print("DTYPES:\n{}\n".format(dataframe.dtypes))
    print("SHAPE:\n{}\n".format(dataframe.shape))
    print("DESCRIBE:\n{}\n".format(dataframe.describe().T))
    print("HEAD:\n{}\n".format(dataframe.head(5).T))
# Chuck EDA function (extracted unique portion)
def eda_unique(dataframe):
    for item in dataframe:
        print(item)
        print(dataframe[item].nunique())
        
# Scatter Plot (numeric values)
def plt_against_price(sale_price,feature):
    """Input sale_price variable (keep constant) and specific feature for analysis"""
    figure = plt.scatter(sale_price,feature)
    plt.xlabel('Sale Price')
    plt.ylabel('Feature')
    plt.title('Feature v Sale Price');
    return figure

# Histogram (numeric values)
def plt_distribution(feature,bin_num):
    """Input feature variable for distribution as histogram and specified number of bins"""
    figure = plt.hist(feature,bins=bin_num)
    plt.xlabel('Distribution')
    plt.ylabel('Feature')
    plt.title('Feature Distribution')
    return figure
