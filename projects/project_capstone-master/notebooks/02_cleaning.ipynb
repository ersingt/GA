# %% [markdown]
# # Cleaning:

# %%
# Import libraries:

import pandas as pd
import numpy as np

# %% [markdown]
# ## Demographic Data:

# %%
# Load Demographic Data:

demog = pd.read_csv('../data/tabular_data/acs_data/acs_demographic/ACSDP5Y2018.DP05_data_with_overlays_2020-05-13T160540.csv')
demog.head(2)
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
#
#                                          DP05_0031PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                8.2
#
#                                           DP05_0032E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                              105.7
#
#                                           DP05_0032M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               35.3
#
#                                          DP05_0032PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                                (X)
#
#                                          DP05_0032PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                          DP05_0033E                               DP05_0033M  \
# 0  Estimate!!RACE!!Total population  Margin of Error!!RACE!!Total population
# 1                              5160                                      480
#
#                                 DP05_0033PE  ...  \
# 0  Percent Estimate!!RACE!!Total population  ...
# 1                                      5160  ...
#
#                                           DP05_0029M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                160
#
#                                          DP05_0029PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                                864
#
#                                          DP05_0029PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                                           DP05_0030E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                                444
#
#                                           DP05_0030M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                106
#
#                                          DP05_0030PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               51.4
#
#                                          DP05_0030PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                8.2
#
#                                           DP05_0031E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                                420
#
#                                           DP05_0031M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                107
#
#                                          DP05_0031PE
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               48.6
#
# [2 rows x 358 columns]

# %%
# Keep demographic variables of interest:

demog = demog[['GEO_ID',
               'NAME',
               'DP05_0001E',
               'DP05_0002PE',
               'DP05_0018E',
               'DP05_0071PE',
               'DP05_0077PE',
               'DP05_0078PE',
               'DP05_0079PE',
               'DP05_0080PE',
               'DP05_0081PE',
               'DP05_0082PE']]

# %%
# Rename column headers to descriptives (names pulled from metadata table in 'data' folder):

demog = demog.rename(columns={'GEO_ID' : 'geo_id',
                              'NAME' : 'name',
                              'DP05_0001E' : 'total_pop',
                              'DP05_0002PE' : 'pct_male',
                              'DP05_0018E'  : 'median_age',
                              'DP05_0071PE' : 'pct_hisp_latino',
                              'DP05_0077PE' : 'pce_white',
                              'DP05_0078PE' : 'pct_black',
                              'DP05_0079PE' : 'pct_american_ind',
                              'DP05_0080PE' : 'pct_asian',
                              'DP05_0081PE' : 'pct_hawaiian_pacisldr',
                              'DP05_0082PE' : 'pct_other_race',
                              'DP05_0086E'  : 'total_housing_units'})

# %%
# Drop duplicate name row from original census data:

demog = demog.drop([0])
demog.head()
# Out:
#                  geo_id                                               name  \
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
# 2  1400000US11001000201  Census Tract 2.01, District of Columbia, Distr...
# 3  1400000US11001000202  Census Tract 2.02, District of Columbia, Distr...
# 4  1400000US11001000300  Census Tract 3, District of Columbia, District...
# 5  1400000US11001000400  Census Tract 4, District of Columbia, District...
#
#   total_pop pct_male median_age pct_hisp_latino pce_white pct_black  \
# 1      5160     47.2       41.3            14.6      76.1       0.7
# 2      3817     46.7       19.8             9.9      57.2       8.7
# 3      4541     50.8       27.5             8.9      74.3       5.9
# 4      6334     44.9       31.5             6.6      77.1       7.3
# 5      1428     42.6       45.7            15.6      72.5       3.0
#
#   pct_american_ind pct_asian pct_hawaiian_pacisldr pct_other_race
# 1              0.0       6.2                   0.0            0.0
# 2              0.2      18.5                   0.0            0.0
# 3              0.9       6.3                   0.3            0.0
# 4              0.0       7.4                   0.0            0.0
# 5              0.0       6.2                   0.0            0.0

# %%
# Observe columns:

demog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 1 to 181
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   geo_id                 181 non-null    object
#  1   name                   181 non-null    object
#  2   total_pop              181 non-null    object
#  3   pct_male               181 non-null    object
#  4   median_age             181 non-null    object
#  5   pct_hisp_latino        181 non-null    object
#  6   pce_white              181 non-null    object
#  7   pct_black              181 non-null    object
#  8   pct_american_ind       181 non-null    object
#  9   pct_asian              181 non-null    object
#  10  pct_hawaiian_pacisldr  181 non-null    object
#  11  pct_other_race         181 non-null    object
# dtypes: object(12)
# memory usage: 18.4+ KB

# %% [markdown]
# ## Economic Data:

# %%
# Load Data:

econ = pd.read_csv('../data/tabular_data/acs_data/acs_econ/ACSDP5Y2018.DP03_data_with_overlays_2020-05-13T155408.csv')
econ.head(2)
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               4282
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                361
#
#                                          DP03_0001PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                               4282
#
#                                          DP03_0001PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
# 1                                                (X)
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               3323
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                322
#
#                                          DP03_0002PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                               77.6
#
#                                          DP03_0002PM  ...  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...  ...
# 1                                                5.6  ...
#
#                                          DP03_0135PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                2.5
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                3.9
#
#                                           DP03_0136E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0136M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0136PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                2.6
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                3.1
#
#                                           DP03_0137E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0137M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0137PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                               11.0
#
#                                          DP03_0137PM
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                9.5
#
# [2 rows x 550 columns]

# %%
# Keep Economic Variables of Interest:

demog = demog[['GEO_ID',
               'NAME',
               'DP03_0005PE' : 'pct_unemployed',
               'DP03_0025E' : 'avg_wrk_commute_mins',
               'DP03_0062PE' : 'median_hsld_income',
               'DP03_0088E' : 'per_cap_income'
              
              ]]
