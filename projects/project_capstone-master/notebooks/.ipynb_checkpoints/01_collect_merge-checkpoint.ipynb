# %% [markdown]
# # Cleaning:

# %%
# Import libraries:

import pandas as pd
import numpy as np
from functools import reduce

# %% [markdown]
# ## Demographic Data:

# %%
# Load Demographic Data:

demog = pd.read_csv('../data/tabular_data/acs_data/acs_demographic/ACSDP5Y2018.DP05_data_with_overlays_2020-05-13T160540.csv')
demog.head(2)
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
#
#                                          DP05_0031PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                8.2
#
#                                           DP05_0032E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                              105.7
#
#                                           DP05_0032M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               35.3
#
#                                          DP05_0032PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                                (X)
#
#                                          DP05_0032PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                          DP05_0033E                               DP05_0033M  \
# 0  Estimate!!RACE!!Total population  Margin of Error!!RACE!!Total population
# 1                              5160                                      480
#
#                                 DP05_0033PE  ...  \
# 0  Percent Estimate!!RACE!!Total population  ...
# 1                                      5160  ...
#
#                                           DP05_0029M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                160
#
#                                          DP05_0029PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                                864
#
#                                          DP05_0029PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                                           DP05_0030E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                                444
#
#                                           DP05_0030M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                106
#
#                                          DP05_0030PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               51.4
#
#                                          DP05_0030PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                8.2
#
#                                           DP05_0031E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                                420
#
#                                           DP05_0031M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                107
#
#                                          DP05_0031PE
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               48.6
#
# [2 rows x 358 columns]

# %%
# Keep demographic variables of interest:

demog = demog[['GEO_ID',
               'NAME',
               'DP05_0001E',
               'DP05_0002PE',
               'DP05_0018E',
               'DP05_0071PE',
               'DP05_0077PE',
               'DP05_0078PE',
               'DP05_0079PE',
               'DP05_0080PE',
               'DP05_0081PE',
               'DP05_0082PE']]

# %%
# Rename column headers to descriptives (names pulled from metadata table in 'data' folder):

demog = demog.rename(columns={'GEO_ID' : 'geo_id',
                              'NAME' : 'name',
                              'DP05_0001E' : 'total_pop',
                              'DP05_0002PE' : 'pct_male',
                              'DP05_0018E'  : 'median_age',
                              'DP05_0071PE' : 'pct_hisp_latino',
                              'DP05_0077PE' : 'pce_white',
                              'DP05_0078PE' : 'pct_black',
                              'DP05_0079PE' : 'pct_american_ind',
                              'DP05_0080PE' : 'pct_asian',
                              'DP05_0081PE' : 'pct_hawaiian_pacisldr',
                              'DP05_0082PE' : 'pct_other_race',
                              'DP05_0086E'  : 'total_housing_units'})

# %%
# Drop duplicate name row from original census data:

demog = demog.drop([0])
demog.head()
# Out:
#                  geo_id                                               name  \
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
# 2  1400000US11001000201  Census Tract 2.01, District of Columbia, Distr...
# 3  1400000US11001000202  Census Tract 2.02, District of Columbia, Distr...
# 4  1400000US11001000300  Census Tract 3, District of Columbia, District...
# 5  1400000US11001000400  Census Tract 4, District of Columbia, District...
#
#   total_pop pct_male median_age pct_hisp_latino pce_white pct_black  \
# 1      5160     47.2       41.3            14.6      76.1       0.7
# 2      3817     46.7       19.8             9.9      57.2       8.7
# 3      4541     50.8       27.5             8.9      74.3       5.9
# 4      6334     44.9       31.5             6.6      77.1       7.3
# 5      1428     42.6       45.7            15.6      72.5       3.0
#
#   pct_american_ind pct_asian pct_hawaiian_pacisldr pct_other_race
# 1              0.0       6.2                   0.0            0.0
# 2              0.2      18.5                   0.0            0.0
# 3              0.9       6.3                   0.3            0.0
# 4              0.0       7.4                   0.0            0.0
# 5              0.0       6.2                   0.0            0.0

# %%
# Observe columns:

demog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 1 to 181
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   geo_id                 181 non-null    object
#  1   name                   181 non-null    object
#  2   total_pop              181 non-null    object
#  3   pct_male               181 non-null    object
#  4   median_age             181 non-null    object
#  5   pct_hisp_latino        181 non-null    object
#  6   pce_white              181 non-null    object
#  7   pct_black              181 non-null    object
#  8   pct_american_ind       181 non-null    object
#  9   pct_asian              181 non-null    object
#  10  pct_hawaiian_pacisldr  181 non-null    object
#  11  pct_other_race         181 non-null    object
# dtypes: object(12)
# memory usage: 18.4+ KB

# %% [markdown]
# ## Economic Data:

# %%
# Load Data:

econ = pd.read_csv('../data/tabular_data/acs_data/acs_econ/ACSDP5Y2018.DP03_data_with_overlays_2020-05-13T155408.csv')
econ.head(2)
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               4282
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                361
#
#                                          DP03_0001PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                               4282
#
#                                          DP03_0001PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
# 1                                                (X)
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               3323
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                322
#
#                                          DP03_0002PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                               77.6
#
#                                          DP03_0002PM  ...  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...  ...
# 1                                                5.6  ...
#
#                                          DP03_0135PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                2.5
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                3.9
#
#                                           DP03_0136E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0136M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0136PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                2.6
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                3.1
#
#                                           DP03_0137E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0137M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0137PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                               11.0
#
#                                          DP03_0137PM
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                9.5
#
# [2 rows x 550 columns]

# %%
# Keep Economic Variables of Interest:

econ = econ[['GEO_ID',
               'NAME',
               'DP03_0005PE',
               'DP03_0025E',
               'DP03_0062E',
               'DP03_0088E'
              ]]

# %%
# Rename column headers to descriptives (names pulled from metadata table in 'data' folder):

econ = econ.rename(columns={'GEO_ID': 'geo_id',
                             'NAME': 'name',
                             'DP03_0005PE' : 'pct_unemployed',
                             'DP03_0025E' : 'avg_wrk_commute_mins',
                             'DP03_0062E' : 'median_hsld_income',
                             'DP03_0088E' : 'per_cap_income'
                             })

# %%
# Drop duplicate name row from original census data:

econ = econ.drop([0])
econ.head()
# Out:
#                  geo_id                                               name  \
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
# 2  1400000US11001000201  Census Tract 2.01, District of Columbia, Distr...
# 3  1400000US11001000202  Census Tract 2.02, District of Columbia, Distr...
# 4  1400000US11001000300  Census Tract 3, District of Columbia, District...
# 5  1400000US11001000400  Census Tract 4, District of Columbia, District...
#
#   pct_unemployed avg_wrk_commute_mins median_hsld_income per_cap_income
# 1            1.8                 24.2             191146         136192
# 2            2.1                 13.3                  -           3743
# 3            2.3                 21.3             170987          79611
# 4            2.0                 25.3             152120          75083
# 5            0.4                 25.6             126731         137970

# %%
# Check Econ data:

econ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 1 to 181
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   geo_id                181 non-null    object
#  1   name                  181 non-null    object
#  2   pct_unemployed        181 non-null    object
#  3   avg_wrk_commute_mins  181 non-null    object
#  4   median_hsld_income    181 non-null    object
#  5   per_cap_income        181 non-null    object
# dtypes: object(6)
# memory usage: 9.9+ KB

# %% [markdown]
# ## Social Data:

# %%
# Load Data:

social = pd.read_csv('../data/tabular_data/acs_data/acs_social/ACSDP5Y2018.DP02_data_with_overlays_2020-05-13T154111.csv')
social.head(2)
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
#
#                                        DP02_0001E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1                                            2351
#
#                                           DP02_0001M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                                186
#
#                                          DP02_0001PE  \
# 0  Percent Estimate!!HOUSEHOLDS BY TYPE!!Total ho...
# 1                                               2351
#
#                                          DP02_0001PM  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...
# 1                                                (X)
#
#                                           DP02_0002E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                               1206
#
#                                           DP02_0002M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                                180
#
#                                          DP02_0002PE  \
# 0  Percent Estimate!!HOUSEHOLDS BY TYPE!!Total ho...
# 1                                               51.3
#
#                                          DP02_0002PM  ...  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...  ...
# 1                                                6.6  ...
#
#                                          DP02_0150PE  \
# 0  Percent Estimate!!COMPUTERS AND INTERNET USE!!...
# 1                                               2351
#
#                                          DP02_0150PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                (X)
#
#                                           DP02_0151E  \
# 0  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 1                                               2333
#
#                                           DP02_0151M  \
# 0  Margin of Error!!COMPUTERS AND INTERNET USE!!T...
# 1                                                190
#
#                                          DP02_0151PE  \
# 0  Percent Estimate!!COMPUTERS AND INTERNET USE!!...
# 1                                               99.2
#
#                                          DP02_0151PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                1.2
#
#                                           DP02_0152E  \
# 0  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 1                                               2303
#
#                                           DP02_0152M  \
# 0  Margin of Error!!COMPUTERS AND INTERNET USE!!T...
# 1                                                189
#
#                                          DP02_0152PE  \
# 0  Percent Estimate!!COMPUTERS AND INTERNET USE!!...
# 1                                               98.0
#
#                                          DP02_0152PM
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                1.9
#
# [2 rows x 610 columns]

# %%
# Keep Social Variables of Interest:

social = social[['GEO_ID',
               'NAME',
               'DP02_0001E',
               'DP02_0015E',
               'DP02_0016E',
               'DP02_0017E',
               'DP02_0067PE',
                ]]

# %%
# Rename column headers to descriptives (names pulled from metadata table in 'data' folder):

social = social.rename(columns={'GEO_ID' : 'geo_id',
               'NAME' : 'name',
               'DP02_0001E'  : 'total_households',
               'DP02_0015E'  : 'avg_household_size',
               'DP02_0016E'  : 'avg_family_size',
               'DP02_0017E'  : 'pop_in_households',
               'DP02_0067PE' : 'pct_bach_degree'
                })

# %%
# Drop duplicate name row from original census data:

social = social.drop([0])
social.head()
# Out:
#                  geo_id                                               name  \
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
# 2  1400000US11001000201  Census Tract 2.01, District of Columbia, Distr...
# 3  1400000US11001000202  Census Tract 2.02, District of Columbia, Distr...
# 4  1400000US11001000300  Census Tract 3, District of Columbia, District...
# 5  1400000US11001000400  Census Tract 4, District of Columbia, District...
#
#   total_households avg_household_size avg_family_size pop_in_households  \
# 1             2351               2.19            2.72              5147
# 2                0                  -               -                 0
# 3             1563               2.26            2.62              3540
# 4             2455               2.58            3.00              6334
# 5              618               2.27            3.18              1401
#
#   pct_bach_degree
# 1            89.6
# 2           100.0
# 3            90.5
# 4            91.1
# 5            82.0

# %%
social.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 1 to 181
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   geo_id              181 non-null    object
#  1   name                181 non-null    object
#  2   total_households    181 non-null    object
#  3   avg_household_size  181 non-null    object
#  4   avg_family_size     181 non-null    object
#  5   pop_in_households   181 non-null    object
#  6   educ_attnmnt        181 non-null    object
# dtypes: object(7)
# memory usage: 11.3+ KB

# %% [markdown]
# ## Housing Data:

# %%
# Load Data:

housing = pd.read_csv('../data/tabular_data/acs_data/acs_housing/ACSDP5Y2018.DP04_data_with_overlays_2020-05-13T160113.csv')
housing.head(2)
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                              2805
#
#                                           DP04_0001M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                                131
#
#                                          DP04_0001PE  \
# 0  Percent Estimate!!HOUSING OCCUPANCY!!Total hou...
# 1                                               2805
#
#                                          DP04_0001PM  \
# 0  Percent Margin of Error!!HOUSING OCCUPANCY!!To...
# 1                                                (X)
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                               2351
#
#                                           DP04_0002M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                                186
#
#                                          DP04_0002PE  \
# 0  Percent Estimate!!HOUSING OCCUPANCY!!Total hou...
# 1                                               83.8
#
#                                          DP04_0002PM  ...  \
# 0  Percent Margin of Error!!HOUSING OCCUPANCY!!To...  ...
# 1                                                6.7  ...
#
#                                          DP04_0141PE  \
# 0  Percent Estimate!!GROSS RENT AS A PERCENTAGE O...
# 1                                               18.1
#
#                                          DP04_0141PM  \
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...
# 1                                               10.4
#
#                                           DP04_0142E  \
# 0  Estimate!!GROSS RENT AS A PERCENTAGE OF HOUSEH...
# 1                                                195
#
#                                           DP04_0142M  \
# 0  Margin of Error!!GROSS RENT AS A PERCENTAGE OF...
# 1                                                122
#
#                                          DP04_0142PE  \
# 0  Percent Estimate!!GROSS RENT AS A PERCENTAGE O...
# 1                                               19.3
#
#                                          DP04_0142PM  \
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...
# 1                                               12.1
#
#                                           DP04_0143E  \
# 0  Estimate!!GROSS RENT AS A PERCENTAGE OF HOUSEH...
# 1                                                 48
#
#                                           DP04_0143M  \
# 0  Margin of Error!!GROSS RENT AS A PERCENTAGE OF...
# 1                                                 42
#
#                                          DP04_0143PE  \
# 0  Percent Estimate!!GROSS RENT AS A PERCENTAGE O...
# 1                                                (X)
#
#                                          DP04_0143PM
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...
# 1                                                (X)
#
# [2 rows x 574 columns]

# %%
# Keep Housing Variables of Interest:

housing = housing[['GEO_ID',
               'NAME',
               'DP04_0001E',
               'DP04_0002E',
               'DP04_0006E',
               'DP04_0017E',
               'DP04_0046E',
               'DP04_0047E'
               ]]

# %%
# Rename column headers to descriptives (names pulled from metadata table in 'data' folder):

housing = housing.rename(columns={'GEO_ID' : 'geo_id',
               'NAME' : 'name',
               'DP04_0001E' : 'total_housing_units',
               'DP04_0002E' : 'occupied_housing_units',
               'DP04_0006E' : 'total_units_in_structure',
               'DP04_0017E' : 'units_built_after_2014',
               'DP04_0046E' : 'owner_occupied_units',
               'DP04_0047E' : 'renter_occupied_units'
                })

# %%
# Drop duplicate name row from original census data:

housing = housing.drop([0])
housing.head()
# Out:
#                  geo_id                                               name  \
# 1  1400000US11001000100  Census Tract 1, District of Columbia, District...
# 2  1400000US11001000201  Census Tract 2.01, District of Columbia, Distr...
# 3  1400000US11001000202  Census Tract 2.02, District of Columbia, Distr...
# 4  1400000US11001000300  Census Tract 3, District of Columbia, District...
# 5  1400000US11001000400  Census Tract 4, District of Columbia, District...
#
#   total_housing_units occupied_housing_units total_units_in_structure  \
# 1                2805                   2351                     2805
# 2                   0                      0                        0
# 3                1852                   1563                     1852
# 4                2540                   2455                     2540
# 5                 720                    618                      720
#
#   units_built_after_2014 owner_occupied_units renter_occupied_units
# 1                      0                 1294                  1057
# 2                      0                    0                     0
# 3                     21                 1063                   500
# 4                     20                 1234                  1221
# 5                     28                  354                   264

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 1 to 181
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   geo_id                    181 non-null    object
#  1   name                      181 non-null    object
#  2   total_housing_units       181 non-null    object
#  3   occupied_housing_units    181 non-null    object
#  4   total_units_in_structure  181 non-null    object
#  5   units_built_after_2014    181 non-null    object
#  6   owner_occupied_units      181 non-null    object
#  7   renter_occupied_units     181 non-null    object
# dtypes: object(8)
# memory usage: 12.7+ KB

# %% [markdown]
# ## Merge Dataframes:

# %%
# Create list of Dataframes:

dfs = [demog, econ, social, housing]

# %%
# Merge:

merged = reduce(lambda left,right: pd.merge(left,right,on='geo_id'), dfs)

# %%
merged.shape
# Out:
# (181, 30)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 0 to 180
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   geo_id                    181 non-null    object
#  1   name_x                    181 non-null    object
#  2   total_pop                 181 non-null    object
#  3   pct_male                  181 non-null    object
#  4   median_age                181 non-null    object
#  5   pct_hisp_latino           181 non-null    object
#  6   pce_white                 181 non-null    object
#  7   pct_black                 181 non-null    object
#  8   pct_american_ind          181 non-null    object
#  9   pct_asian                 181 non-null    object
#  10  pct_hawaiian_pacisldr     181 non-null    object
#  11  pct_other_race            181 non-null    object
#  12  name_y                    181 non-null    object
#  13  pct_unemployed            181 non-null    object
#  14  avg_wrk_commute_mins      181 non-null    object
#  15  median_hsld_income        181 non-null    object
#  16  per_cap_income            181 non-null    object
#  17  name_x                    181 non-null    object
#  18  total_households          181 non-null    object
#  19  avg_household_size        181 non-null    object
#  20  avg_family_size           181 non-null    object
#  21  pop_in_households         181 non-null    object
#  22  pct_bach_degree           181 non-null    object
#  23  name_y                    181 non-null    object
#  24  total_housing_units       181 non-null    object
#  25  occupied_housing_units    181 non-null    object
#  26  total_units_in_structure  181 non-null    object
#  27  units_built_after_2014    181 non-null    object
#  28  owner_occupied_units      181 non-null    object
#  29  renter_occupied_units     181 non-null    object
# dtypes: object(30)
# memory usage: 43.8+ KB

# %%
merged.head()
# Out:
#                  geo_id                                             name_x  \
# 0  1400000US11001000100  Census Tract 1, District of Columbia, District...
# 1  1400000US11001000201  Census Tract 2.01, District of Columbia, Distr...
# 2  1400000US11001000202  Census Tract 2.02, District of Columbia, Distr...
# 3  1400000US11001000300  Census Tract 3, District of Columbia, District...
# 4  1400000US11001000400  Census Tract 4, District of Columbia, District...
#
#   total_pop pct_male median_age pct_hisp_latino pce_white pct_black  \
# 0      5160     47.2       41.3            14.6      76.1       0.7
# 1      3817     46.7       19.8             9.9      57.2       8.7
# 2      4541     50.8       27.5             8.9      74.3       5.9
# 3      6334     44.9       31.5             6.6      77.1       7.3
# 4      1428     42.6       45.7            15.6      72.5       3.0
#
#   pct_american_ind pct_asian  ... avg_family_size pop_in_households  \
# 0              0.0       6.2  ...            2.72              5147
# 1              0.2      18.5  ...               -                 0
# 2              0.9       6.3  ...            2.62              3540
# 3              0.0       7.4  ...            3.00              6334
# 4              0.0       6.2  ...            3.18              1401
#
#   pct_bach_degree                                             name_y  \
# 0            89.6  Census Tract 1, District of Columbia, District...
# 1           100.0  Census Tract 2.01, District of Columbia, Distr...
# 2            90.5  Census Tract 2.02, District of Columbia, Distr...
# 3            91.1  Census Tract 3, District of Columbia, District...
# 4            82.0  Census Tract 4, District of Columbia, District...
#
#   total_housing_units occupied_housing_units total_units_in_structure  \
# 0                2805                   2351                     2805
# 1                   0                      0                        0
# 2                1852                   1563                     1852
# 3                2540                   2455                     2540
# 4                 720                    618                      720
#
#   units_built_after_2014 owner_occupied_units renter_occupied_units
# 0                      0                 1294                  1057
# 1                      0                    0                     0
# 2                     21                 1063                   500
# 3                     20                 1234                  1221
# 4                     28                  354                   264
#
# [5 rows x 30 columns]
