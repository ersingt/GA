# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Plan, based on EDA:
#
# #### Generate:
#
#  - pop_densitty: total_pop / total_housing_units
#  - pct_other_race = pct_americanind + pct_pacislndr + pct_other
#
# #### Drop after generation:
#  - occupied_housing_units
#  - total_units_in_structure
#  - pop_in_households
#  - per_cap_income
#  - avg_family_size
#  - pct_male
#  - total_households
#  - units_built_after_2014
#  - owner_occupied_units
#
# #### Tranform:
#  - Log transform variables for
#  - Convert all variables to Z-scores prior to clustering (standard scalar)

# %% [markdown]
# ## Import Libraries and Read in Data:

# %%
# Import Libraries:

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.preprocessing import StandardScaler

import requests

# %%
# Read data:

df = pd.read_csv('../data/outputs/02_merged_clean.csv', index_col='geo_id')

# %%
df.head(2)
# Out:
#                                                                  name_x  \
# geo_id
# 1400000US11001000100  Census Tract 1, District of Columbia, District...
# 1400000US11001000202  Census Tract 2.02, District of Columbia, Distr...
#
#                       total_pop  pct_male  median_age  pct_hisp_latino  \
# geo_id
# 1400000US11001000100       5160      47.2        41.3             14.6
# 1400000US11001000202       4541      50.8        27.5              8.9
#
#                       pct_white  pct_black  pct_american_ind  pct_asian  \
# geo_id
# 1400000US11001000100       76.1        0.7               0.0        6.2
# 1400000US11001000202       74.3        5.9               0.9        6.3
#
#                       pct_hawaiian_pacisldr  ...  pop_in_households  \
# geo_id                                       ...
# 1400000US11001000100                    0.0  ...               5147
# 1400000US11001000202                    0.3  ...               3540
#
#                       pct_bach_degree  total_housing_units  \
# geo_id
# 1400000US11001000100             89.6                 2805
# 1400000US11001000202             90.5                 1852
#
#                       occupied_housing_units  total_units_in_structure  \
# geo_id
# 1400000US11001000100                    2351                      2805
# 1400000US11001000202                    1563                      1852
#
#                       units_built_after_2014  owner_occupied_units  \
# geo_id
# 1400000US11001000100                       0                  1294
# 1400000US11001000202                      21                  1063
#
#                       renter_occupied_units  median_rent  median_home_value
# geo_id
# 1400000US11001000100                   1057         2289            1333300
# 1400000US11001000202                    500         2398            1179700
#
# [2 rows x 28 columns]

# %% [markdown]
# ## Generate Features:

# %%
# Generate 'Percent Other Race':

df['pct_other_minority'] = df['pct_american_ind'] + df['pct_hawaiian_pacisldr'] + df['pct_other_race']
df['pct_other_minority'].describe()
# Out:
# count    177.000000
# mean       0.635593
# std        0.971836
# min        0.000000
# 25%        0.000000
# 50%        0.300000
# 75%        0.800000
# max        6.800000
# Name: pct_other_minority, dtype: float64

# %%
# Generate 'Population Density':

df['pop_density'] = df['total_pop'] / df['total_housing_units']
df['pop_density'].describe()
# Out:
# count    177.000000
# mean       2.737228
# std        6.089505
# min        1.244501
# 25%        1.945904
# 50%        2.259402
# 75%        2.528816
# max       82.937500
# Name: pop_density, dtype: float64

# %%
# Generate 'Percent Renter Occupied Units':

df['pct_renter_occupied'] = df['renter_occupied_units'] / df['total_housing_units']
df['pct_renter_occupied'].describe()
# Out:
# count    177.000000
# mean       0.508579
# std        0.194441
# min        0.000000
# 25%        0.376827
# 50%        0.521586
# 75%        0.668478
# max        0.925524
# Name: pct_renter_occupied, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 177 entries, 1400000US11001000100 to 1400000US11001011100
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name_x                    177 non-null    object
#  1   total_pop                 177 non-null    int64
#  2   pct_male                  177 non-null    float64
#  3   median_age                177 non-null    float64
#  4   pct_hisp_latino           177 non-null    float64
#  5   pct_white                 177 non-null    float64
#  6   pct_black                 177 non-null    float64
#  7   pct_american_ind          177 non-null    float64
#  8   pct_asian                 177 non-null    float64
#  9   pct_hawaiian_pacisldr     177 non-null    float64
#  10  pct_other_race            177 non-null    float64
#  11  pct_unemployed            177 non-null    float64
#  12  avg_wrk_commute_mins      177 non-null    float64
#  13  median_hsld_income        177 non-null    int64
#  14  per_cap_income            177 non-null    int64
#  15  total_households          177 non-null    int64
#  16  avg_household_size        177 non-null    float64
#  17  avg_family_size           177 non-null    float64
#  18  pop_in_households         177 non-null    int64
#  19  pct_bach_degree           177 non-null    float64
#  20  total_housing_units       177 non-null    int64
#  21  occupied_housing_units    177 non-null    int64
#  22  total_units_in_structure  177 non-null    int64
#  23  units_built_after_2014    177 non-null    int64
#  24  owner_occupied_units      177 non-null    int64
#  25  renter_occupied_units     177 non-null    int64
#  26  median_rent               177 non-null    int64
#  27  median_home_value         177 non-null    int64
#  28  pct_other_minority        177 non-null    float64
#  29  pop_density               177 non-null    float64
#  30  pct_renter_occupied       177 non-null    float64
# dtypes: float64(17), int64(13), object(1)
# memory usage: 44.2+ KB

# %% [markdown]
# ## Drop Features for Modeling:

# %%
# Drop features unneeded for modeling, features highly correlated with other variavles, and/or used only for feature generation:

df = df.drop(columns=['pct_american_ind', 
   'pct_hawaiian_pacisldr', 
   'pct_other_race', 
   'total_pop', 
   'total_housing_units', 
   'occupied_housing_units', 
   'total_units_in_structure', 
   'pop_in_households', 
   'per_cap_income', 
   'avg_family_size', 
   'pct_male', 
   'total_households',
   'units_built_after_2014',
   'owner_occupied_units',
   'renter_occupied_units',
   'median_home_value',
   'pct_white'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 177 entries, 1400000US11001000100 to 1400000US11001011100
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name_x                177 non-null    object
#  1   median_age            177 non-null    float64
#  2   pct_hisp_latino       177 non-null    float64
#  3   pct_black             177 non-null    float64
#  4   pct_asian             177 non-null    float64
#  5   pct_unemployed        177 non-null    float64
#  6   avg_wrk_commute_mins  177 non-null    float64
#  7   median_hsld_income    177 non-null    int64
#  8   avg_household_size    177 non-null    float64
#  9   pct_bach_degree       177 non-null    float64
#  10  median_rent           177 non-null    int64
#  11  pct_other_minority    177 non-null    float64
#  12  pop_density           177 non-null    float64
#  13  pct_renter_occupied   177 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 20.7+ KB

# %%
# Heat Map Correlation Matrix:

plt.figure(figsize=(20,15))
sns.set(font_scale=1.2)
plt.title('Correlation Matrix', fontsize=18)
mask = np.triu(df.corr())
ax = sns.heatmap(df.corr(), annot=True, cmap='coolwarm', 
                 linewidths=.5, mask=mask);

# %% [markdown]
# # Export Engineered Data for Modeling:

# %%
# Export without index:

df.to_csv('../data/outputs/03_merged_clean_engineered.csv', index='geo_id')

# %%
# Consider returning to drop pct_white, pct_bach_degree, and median_hsld_income
